# %% [markdown]
# <a href="https://colab.research.google.com/github/awaistechsolution9/assigment-04/blob/main/01_double_it.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
number = float(input("Enter a number"))

while number < 100:
  number *2
  print(f"Doubled value" ,{number} )
# Out:
# Streaming output truncated to the last 5000 lines.
# Doubled value {5.0}
# Doubled value {5.0}
# Doubled value {5.0}
# Doubled value {5.0}
# Doubled value {5.0}
# Doubled value {5.0}
# Doubled value {5.0}
# Doubled value {5.0}
# Doubled value {5.0}
# Doubled value {5.0}
# Doubled value {5.0}
# Doubled value {5.0}
# Doubled value {5.0}
# Doubled value {5.0}
# Doubled value {5.0}
# Doubled value {5.0}
# Doubled value {5.0}
# Doubled value {5.0}
# Doubled value {5.0}
# Doubled value {5.0}
# Doubled value {5.0}
# Doubled value {5.0}
# Doubled value {5.0}
# Doubled value {5.0}
# Doubled value {5.0}
# Doubled value {5.0}
# Doubled value {5.0}
# Doubled value {5.0}
# Doubled value {5.0}
# Doubled value {5.0}
# Doubled value {5.0}
# Doubled value {5.0}
# Doubled value {5.0}
# Doubled value {5.0}
# Doubled value {5.0}
# Doubled value {5.0}
# Doubled value {5.0}
# Doubled value {5.0}
# Doubled value {5.0}
# Doubled value {5.0}
# Doubled value {5.0}
# Doubled value {5.0}
# Doubled value {5.0}
# ...
